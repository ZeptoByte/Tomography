# %%
from Final_Project.atm_muon import *
import matplotlib.pyplot as plt

energies = np.geomspace(1,1e4,1000)


time = 10*86400
flux = muon_flux_Gaisser(energies, np.radians(0))

# %%
plt.figure()
plt.plot(energies, muon_flux_Gaisser(energies, np.radians(0)))
plt.plot(energies, muon_flux_Gaisser(energies, np.radians(90)))
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
np.cos(np.radians(90))
# Out:
# 6.123233995736766e-17
